# %%
# Initial imports
import pandas as pd
from pathlib import Path

# %%
file_path=("financing_healthcare/annual-healthcare-expenditure-per-capita.csv")
annual_expenditure=pd.read_csv(file_path)
annual_expenditure.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2002
# 1  Afghanistan  AFG  2003
# 2  Afghanistan  AFG  2004
# 3  Afghanistan  AFG  2005
# 4  Afghanistan  AFG  2006
#
#    Indicator:Current health expenditure (CHE) per capita in PPP int$
# 0                                              81.27
# 1                                              82.46
# 2                                              89.47
# 3                                             100.71
# 4                                             113.75

# %%
file_path=("financing_healthcare/child-mortality-vs-health-expenditure.csv")
child_mortality=pd.read_csv(file_path)
child_mortality.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1960
# 2  Afghanistan       AFG  1961
# 3  Afghanistan       AFG  1962
# 4  Afghanistan       AFG  1963
#
#    Mortality rate, under-5 (per 1,000 live births)  \
# 0                                              NaN
# 1                                        35.820001
# 2                                        35.220001
# 3                                        34.629999
# 4                                        34.060001
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# ...

# %%
file_path=("financing_healthcare/healthcare-expenditure-vs-gdp.csv")
gdp=pd.read_csv(file_path)
gdp.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  2002
# 2  Afghanistan       AFG  2003
# 3  Afghanistan       AFG  2004
# 4  Afghanistan       AFG  2005
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                                NaN
# 1                                          81.271034
# 2                                          82.457848
# 3                                          89.470055
# 4                                         100.706985
#
#    GDP per capita, PPP (current international $)  \
# 0                                            NaN
# 1                                     877.014282
# 2                                     927.857544
# 3                                     925.441406
# 4                                    1023.051758
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# ...

# %%
file_path=("financing_healthcare/health-protection-coverage.csv")
coverage=pd.read_csv(file_path)
coverage.head()
# Out:
#                 Entity Code  Year  \
# 0              Albania  ALB  2008
# 1              Algeria  DZA  2005
# 2       American Samoa  ASM  2009
# 3               Angola  AGO  2010
# 4  Antigua and Barbuda  ATG  2007
#
#    Share of population covered by health insurance (ILO (2014))
# 0                                               23.6
# 1                                               85.2
# 2                                                3.0
# 3                                                0.0
# 4                                               51.1

# %%
file_path=("financing_healthcare/health-protection-coverage.csv")
coverage=pd.read_csv(file_path)
coverage.head()
